# %%
from gspan_mining.config import parser
from gspan_mining.main import main

# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
args_str = '-s 2 -d True -l 5 -p True -w True graphdata/graph.data.simple.5'
FLAGS, _ = parser.parse_known_args(args=args_str.split())

# %%
gs = main(FLAGS)
# Out:
# t # 0
# v 0 2
# v 1 2
# v 2 3
# v 3 4
# v 4 2
# e 0 1 2
# e 0 4 2
# e 1 2 3
# e 2 3 2
#
# Support: 2
# /Users/tangting/Project/gSpan-master/gspan_mining/gspan.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._report_df = self._report_df.append(
# where: [0, 3]
#
# -----------------
#
# t # 1
# v 0 2
# v 1 2
# v 2 2
# v 3 3
# v 4 4
# e 0 1 2
# e 1 2 2
# e 1 3 3
# e 3 4 2
#
# Support: 2
# /Users/tangting/Project/gSpan-master/gspan_mining/gspan.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._report_df = self._report_df.append(
# where: [0, 3]
#
# -----------------
#
# t # 2
# v 0 2
# v 1 2
# v 2 2
# v 3 3
# v 4 4
# v 5 2
# e 0 1 2
# e 0 5 2
# e 1 2 2
# e 1 3 3
# e 3 4 2
#
# Support: 2
# /Users/tangting/Project/gSpan-master/gspan_mining/gspan.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._report_df = self._report_df.append(
# where: [0, 3]
#
# -----------------
#
# t # 3
# v 0 2
# v 1 2
# v 2 2
# v 3 3
# v 4 2
# e 0 1 2
# e 0 4 2
# e 1 2 2
# e 1 3 3
#
# Support: 2
# /Users/tangting/Project/gSpan-master/gspan_mining/gspan.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self._report_df = self._report_df.append(
# where: [0, 3]
#
# -----------------
#
# Read:	0.0 s
# Mine:	1.24 s
# Total:	1.24 s

# %% [markdown]
# ## plot graphs in database

# %%
for g in gs.graphs.values():
    g.plot()
